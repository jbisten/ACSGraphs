# %% [markdown]
# # Plotting Cluster Intersections

# %%
from visualization import plot_cluster_intersections, get_plane_intersection, get_tangent_and_plane, load_cluster_ply, plot_slice_intersections

# %%
streamlines, sub_ids, cluster_ids = load_cluster_ply('/home/justus/datasets/justus_kleine_denkmurmel/derivatives/sub-00001/ses-20240402/dwi/tracts/clusters.ply')

# %%
streamlines.shape
# Out:
# (8473, 21, 3)

# %%
sub_ids.shape
# Out:
# (8473,)

# %%
cluster_ids.shape
# Out:
# (8473,)

# %%
import numpy as np
center = np.mean(streamlines, axis=0)
center.shape
tangent, plane = get_tangent_and_plane(center, 10)

# %%
tangent
# Out:
# array([0.12951276, 0.7906052 , 0.5984731 ], dtype=float32)

# %%
plane
# Out:
# (0.12951276, 0.7906052, 0.5984731, -11.243968)

# %%
plot_slice_intersections('/home/justus/datasets/justus_kleine_denkmurmel/derivatives/sub-00001/ses-20240402/dwi/preproc/wm.nii.gz', streamlines, cluster_ids, 40, 2, 'axial')
