# %%
from clustering.analysis.statistics import ClusterPly, Cluster

# %%
plycluster = ClusterPly('/home/justus/publications/hemi_lang_func/data/derivatives/clustering/kmeans_results/clusters.ply', participants_tsv='/home/justus/publications/hemi_lang_func/data/participants.tsv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 plycluster = ClusterPly('/home/justus/publications/hemi_lang_func/data/derivatives/kmeans/results/clusters.ply', participants_tsv='/home/justus/publications/hemi_lang_func/data/participants.tsv')
#
# File ~/codebase/ACSGraphs/clustering/analysis/statistics.py:51, in ClusterPly.__init__(self, plyfile, participants_tsv)
#      49 ply_in = Path(plyfile)
#      50 assert ply_in.suffix == '.ply', "file is not a .ply-file"
# ---> 51 self.plydata = PlyData.read(ply_in)
#      52 self.cluster_labels = self.plydata['fiber']['clusterid']
#      53 self.participants_df = pd.read_csv(participants_tsv, sep='\t')
#
# File ~/.miniconda3/envs/acsgraphs/lib/python3.12/site-packages/plyfile.py:158, in PlyData.read(stream, mmap, known_list_len)
#     130 @staticmethod
# ...

# %%
plycluster.get_cluster_group_diff(plot=True, param='fa')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 plycluster.get_cluster_group_diff(plot=True, param='fa')
#
# NameError: name 'plycluster' is not defined

# %%
plycluster.get_cluster_diff('fa', plot=True)
# Out:
# Cluster 0: mean fa = 0.4728128910064697
# Cluster 1: mean fa = 0.4763658046722412
# Cluster 2: mean fa = 0.4355793297290802
