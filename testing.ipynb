# %%
from clustering.analysis.statistics import H5Statistics

# %%
stats = H5Statistics('/data/datasets/hemispherotomy/derivatives/clustering/', participants_tsv='/data/datasets/hemispherotomy/participants.tsv')
# Out:
# 74

# %%
import numpy as np
print(np.median(stats.demographics['AgeAtOnset']))
# Out:
# nan

# %%
stats.plot_statistics()
# Out:
# Extracted DataFrame:
#   participant_id    group side_id   mean_fa   mean_ad   mean_rd   mean_md
# 0      sub-00023  control      lh  0.486473  0.001151  0.000526  0.000734
# 1      sub-00042  patient      rh  0.346152  0.001097  0.000656  0.000803
# 2      sub-00028  patient      rh  0.296061  0.001125  0.000726  0.000859
# 3      sub-00026  control      lh  0.482508  0.001154  0.000535  0.000741
# 4      sub-00009  control      lh  0.511662  0.001151  0.000487  0.000709
# DataFrame columns: Index(['participant_id', 'group', 'side_id', 'mean_fa', 'mean_ad', 'mean_rd',
#        'mean_md'],
#       dtype='object')
# Side lh, metric mean_fa - Patients: 10, Controls: 25
# T-test for mean_fa on side lh: t=0.7871690233686608, p=0.4429494258795389
# Side rh, metric mean_fa - Patients: 14, Controls: 25
# T-test for mean_fa on side rh: t=-0.7521369378967835, p=0.4620482275622172
# Side lh, metric mean_ad - Patients: 10, Controls: 25
# ...
