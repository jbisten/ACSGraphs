# %%
from clustering.analysis.statistics import ClusterPly, Cluster

# %%
plycluster = ClusterPly('/home/justus/datasets/justus_kleine_denkmurmel/derivatives/kmeans/results_lh/clusters.ply')

# %%
plycluster.get_support()
# Out:
# Cluster0, support for each subject [621]
# Cluster1, support for each subject [455]
# Cluster2, support for each subject [876]
# Cluster3, support for each subject [822]
# Cluster4, support for each subject [287]

# %%
plycluster.get_cluster_diff('fa', plot=True)
# Out:
# Cluster 0: mean fa = 0.5002923011779785
# Cluster 1: mean fa = 0.49707454442977905
# Cluster 2: mean fa = 0.4958045184612274
# Cluster 3: mean fa = 0.4808477461338043
# Cluster 4: mean fa = 0.4981623589992523
